# %% [markdown]
# # Model Using 1/7 Window - Normalized
# ## Both UX and UY

# %%
from tensorflow import keras
import numpy as np
from sklearn.metrics import confusion_matrix
from collections import Counter
from matplotlib import pyplot as plt
import tensorflow as tf
from sklearn.metrics import classification_report
from sklearn.preprocessing import OneHotEncoder

# %%
model = keras.models.load_model(r"C:\Users\bono2\Desktop\Pitching Airfoil\Testing effect of window size\one_seventh.h5")

# %%
dir = r'C:\Users\bono2\Desktop\Pitching Airfoil\dataset\window_normalized\one seventh'

# %%
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# ## TEST DATA

# %%
test_X = np.load(dir + r'\test_X.npy')
test_Y = (np.load(dir + r'\test_Y.npy')).reshape(-1,2)
Y = np.zeros((len(test_Y), 1), dtype = '<U10')
for i in range(len(test_Y)):
    Y[i] = (str(test_Y[i,0])+', '+ str(test_Y[i, 1]))
test_Y = Y

OHE = OneHotEncoder(sparse = False)
test_Y = OHE.fit_transform(test_Y)

OHE.categories_[0]
# Out:
# array(['25.0, 0.05', '25.0, 0.1', '25.0, 0.2', '25.0, 0.25', '25.0, 0.3',
#        '25.0, 0.35', '25.0, 0.4', '25.0, 0.5', '30.0, 0.05', '30.0, 0.1',
#        '30.0, 0.2', '30.0, 0.25', '30.0, 0.3', '30.0, 0.35', '30.0, 0.4',
#        '30.0, 0.5'], dtype='<U10')

# %%
# Get Predictions (reverse to_categorical)
pred_proba = model.predict(test_X)
prediction = np.argmax(pred_proba, axis = 1)
actual = np.argmax(test_Y, axis = 1)
# Out:
# 53/53 [==============================] - 3s 10ms/step

# %%
print(classification_report(actual, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        56
#            1       1.00      1.00      1.00        56
#            2       1.00      1.00      1.00        52
#            3       1.00      1.00      1.00        52
#            4       1.00      1.00      1.00        55
#            5       1.00      1.00      1.00        56
#            6       1.00      0.93      0.96        67
#            7       0.92      1.00      0.96        57
#            8       0.94      0.95      0.94       154
#            9       0.87      0.99      0.92       154
#           10       1.00      1.00      1.00       158
#           11       1.00      1.00      1.00       158
#           12       1.00      1.00      1.00       155
#           13       0.97      0.83      0.90       154
#           14       0.99      0.99      0.99       143
#           15       1.00      1.00      1.00       153
#
#     accuracy                           0.97      1680
#    macro avg       0.98      0.98      0.98      1680
# weighted avg       0.98      0.97      0.97      1680

# %%
correct = 0
wrong_indices = []
wrong_actual = []
wrong_pred = []

for i in range(actual.shape[0]):
    if actual[i] == prediction[i]:
        correct += 1
    else:
        wrong_indices.append(i)
        wrong_pred.append(prediction[i])
        wrong_actual.append(actual[i])


accuracy = correct/int(actual.shape[0])
print("Test Accuracy = ", accuracy)
# Out:
# Test Accuracy =  0.9744047619047619

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(actual, prediction)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(8, 8))
plot_confusion_matrix(cnf_matrix, classes=list(OHE.categories_)[0],normalize=False,
                      title='Confusion matrix')
plt.show()
# Out:
# Confusion matrix, without normalization

# %% [markdown]
# ## VALIDATION DATA

# %%
val_X = np.load(dir + r'\val_X.npy')
val_Y = (np.load(dir + r'\val_Y.npy')).reshape(-1,2)
Y = np.zeros((len(val_Y), 1), dtype = '<U10')
for i in range(len(val_Y)):
    Y[i] = (str(val_Y[i,0])+', '+ str(val_Y[i, 1]))
val_Y = Y

val_Y = OHE.transform(val_Y)

# %%
# Get Predictions (reverse to_categorical)
pred_proba = model.predict(val_X)
prediction = np.argmax(pred_proba, axis = 1)
actual = np.argmax(val_Y, axis = 1)
del val_X
del val_Y
# Out:
# 53/53 [==============================] - 1s 9ms/step

# %%
print(classification_report(actual, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99        68
#            1       1.00      1.00      1.00        68
#            2       1.00      1.00      1.00        65
#            3       1.00      1.00      1.00        69
#            4       1.00      1.00      1.00        77
#            5       1.00      1.00      1.00        59
#            6       1.00      0.98      0.99        54
#            7       0.99      1.00      0.99        69
#            8       0.95      0.96      0.96       142
#            9       0.94      0.99      0.97       142
#           10       1.00      1.00      1.00       145
#           11       1.00      1.00      1.00       141
#           12       0.99      1.00      0.99       133
#           13       0.97      0.89      0.93       151
#           14       0.98      0.99      0.99       156
#           15       1.00      1.00      1.00       141
#
#     accuracy                           0.98      1680
#    macro avg       0.99      0.99      0.99      1680
# weighted avg       0.98      0.98      0.98      1680

# %%
correct = 0
wrong_indices = []
wrong_actual = []
wrong_pred = []

for i in range(actual.shape[0]):
    if actual[i] == prediction[i]:
        correct += 1
    else:
        wrong_indices.append(i)
        wrong_pred.append(prediction[i])
        wrong_actual.append(actual[i])


accuracy = correct/int(actual.shape[0])
print("Validation Accuracy = ", accuracy)
# Out:
# Validation Accuracy =  0.9845238095238096

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(actual, prediction)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(8,8))
plot_confusion_matrix(cnf_matrix, classes=list(OHE.categories_)[0],normalize=False,
                      title='Confusion matrix')
plt.show()
# Out:
# Confusion matrix, without normalization

# %% [markdown]
# ## TRAIN DATA

# %%
train_X = np.load(dir + r'\train_X.npy', mmap_mode='r')
train_Y = (np.load(dir + r'\train_Y.npy')).reshape(-1,2)
Y = np.zeros((len(train_Y), 1), dtype = '<U10')
for i in range(len(train_Y)):
    Y[i] = (str(train_Y[i,0])+', '+ str(train_Y[i, 1]))
train_Y = Y

train_Y = OHE.transform(train_Y)

# Get Predictions (reverse to_categorical)
pred_proba = model.predict(train_X)
prediction = np.argmax(pred_proba, axis = 1)
actual = np.argmax(train_Y, axis = 1)
# Out:
# 246/246 [==============================] - 2s 9ms/step

# %%
print(classification_report(actual, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       277
#            1       1.00      1.00      1.00       277
#            2       1.00      1.00      1.00       284
#            3       1.00      1.00      1.00       280
#            4       1.00      1.00      1.00       269
#            5       1.00      1.00      1.00       286
#            6       1.00      0.95      0.97       280
#            7       0.95      1.00      0.97       275
#            8       0.96      0.96      0.96       705
#            9       0.94      0.98      0.96       705
#           10       1.00      1.00      1.00       698
#           11       1.00      1.00      1.00       702
#           12       1.00      1.00      1.00       713
#           13       0.96      0.90      0.93       696
#           14       0.98      1.00      0.99       702
#           15       1.00      1.00      1.00       707
#
#     accuracy                           0.98      7856
#    macro avg       0.99      0.99      0.99      7856
# weighted avg       0.98      0.98      0.98      7856

# %%
correct = 0
wrong_indices = []
wrong_actual = []
wrong_pred = []

for i in range(actual.shape[0]):
    if actual[i] == prediction[i]:
        correct += 1
    else:
        wrong_indices.append(i)
        wrong_pred.append(prediction[i])
        wrong_actual.append(actual[i])


accuracy = correct/int(actual.shape[0])
print("Train Accuracy = ", accuracy)
# Out:
# Train Accuracy =  0.9834521384928717

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(actual, prediction)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure(figsize=(8, 8))
plot_confusion_matrix(cnf_matrix, classes=list(OHE.categories_)[0],normalize=False,
                      title='Confusion matrix')
plt.show()
# Out:
# Confusion matrix, without normalization
